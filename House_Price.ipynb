# %%
# import
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# read data into a DataFrame
data = pd.read_csv("HOUSE_PRICE.csv")
# preview of first 5 rows
data.head()
# Out:
#    Id  SalePrice MSZoning Condition1 Condition2 KitchenQual HeatingQC  \
# 0   1     208500       RL       Norm       Norm          Gd        Ex
# 1   2     181500       RL      Feedr       Norm          TA        Ex
# 2   3     223500       RL       Norm       Norm          Gd        Ex
# 3   4     140000       RL       Norm       Norm          Gd        Gd
# 4   5     250000       RL       Norm       Norm          Gd        Ex
#
#   CentralAir BsmtCond GarageCond  1stFlrSF  2ndFlrSF  BedroomAbvGr  YearBuilt
# 0          Y       TA         TA       856       854             3       2003
# 1          Y       TA         TA      1262         0             3       1976
# 2          Y       TA         TA       920       866             3       2001
# 3          Y       Gd         TA       961       756             3       1915
# 4          Y       TA         TA      1145      1053             4       2000

# %%
data.set_index('Id',inplace = True)
data.head()
# Out:
#     SalePrice MSZoning Condition1 Condition2 KitchenQual HeatingQC CentralAir  \
# Id
# 1      208500       RL       Norm       Norm          Gd        Ex          Y
# 2      181500       RL      Feedr       Norm          TA        Ex          Y
# 3      223500       RL       Norm       Norm          Gd        Ex          Y
# 4      140000       RL       Norm       Norm          Gd        Gd          Y
# 5      250000       RL       Norm       Norm          Gd        Ex          Y
#
#    BsmtCond GarageCond  1stFlrSF  2ndFlrSF  BedroomAbvGr  YearBuilt
# Id
# 1        TA         TA       856       854             3       2003
# 2        TA         TA      1262         0             3       1976
# 3        TA         TA       920       866             3       2001
# 4        Gd         TA       961       756             3       1915
# 5        TA         TA      1145      1053             4       2000

# %%
data.isnull().sum()
# Out:
# SalePrice       0
# MSZoning        0
# Condition1      0
# Condition2      0
# KitchenQual     0
# HeatingQC       0
# CentralAir      0
# BsmtCond        0
# GarageCond      0
# 1stFlrSF        0
# 2ndFlrSF        0
# BedroomAbvGr    0
# YearBuilt       0
# dtype: int64

# %%
# print the shape of the DataFrame
data.shape
# Out:
# (1460, 13)

# %%
# visualize the relationship between the features and the response using scatterplots
# here only apply scatter plot on numerical variables
fig, axs = plt.subplots(2, 2, sharey=True)
data.plot(kind='scatter', x='YearBuilt', y='SalePrice', ax=axs[0,0], figsize=(16, 12))
data.plot(kind='scatter', x='1stFlrSF', y='SalePrice', ax=axs[0,1])
data.plot(kind='scatter', x='2ndFlrSF', y='SalePrice', ax=axs[1,0])
data.plot(kind='scatter', x='BedroomAbvGr', y='SalePrice', ax=axs[1,1])
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [raw]
# Visualizing the distribution of house prices:

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('House Price Distribution Plot')
sns.distplot(data.SalePrice)

plt.subplot(1,2,2)
plt.title('House Price Outliers Distribution Plot')
sns.boxplot(y=data.SalePrice)
plt.ylabel("Price Range")

plt.show()

# %%
plt.figure(figsize=(9,4))
plt.subplot()
plt.title('House Price Distribution Plot')
sns.distplot(data.SalePrice)
plt.show()

# %% [markdown]
# print(data.SalePrice.describe(percentiles = [0.25,0.50,0.75,0.85,0.90,1]))

# %% [raw]
# Visualising Numeric Variables:
# Pairplot of all the numeric variables

# %%
cat_col = data.select_dtypes(include=['object']).columns
num_col = data.select_dtypes(exclude=['object']).columns
data_cat = data[cat_col]
data_num = data[num_col]

# %%
ax = sns.pairplot(data[num_col])

# %% [raw]
# Visualising few more Categorical Variables:

# %%
plt.figure(figsize=(20, 20))
plt.subplot(4,2,1)
sns.boxplot(x = 'MSZoning', y = 'SalePrice', data = data)
plt.subplot(4,2,2)
sns.boxplot(x = 'Condition1', y = 'SalePrice', data = data)
plt.subplot(4,2,3)
sns.boxplot(x = 'Condition2', y = 'SalePrice', data = data)
plt.subplot(4,2,4)
sns.boxplot(x = 'BsmtCond', y = 'SalePrice', data = data)
plt.subplot(4,2,5)
sns.boxplot(x = 'GarageCond', y = 'SalePrice', data = data)
plt.subplot(4,2,6)
sns.boxplot(x = 'HeatingQC', y = 'SalePrice', data = data)
plt.subplot(4,2,7)
sns.boxplot(x = 'CentralAir', y = 'SalePrice', data = data)
plt.subplot(4,2,8)
sns.boxplot(x = 'KitchenQual', y = 'SalePrice', data = data)
plt.show()

# %%
data.head()
# Out:
#     SalePrice MSZoning Condition1 Condition2 KitchenQual HeatingQC CentralAir  \
# Id
# 1      208500       RL       Norm       Norm          Gd        Ex          Y
# 2      181500       RL      Feedr       Norm          TA        Ex          Y
# 3      223500       RL       Norm       Norm          Gd        Ex          Y
# 4      140000       RL       Norm       Norm          Gd        Gd          Y
# 5      250000       RL       Norm       Norm          Gd        Ex          Y
#
#    BsmtCond GarageCond  1stFlrSF  2ndFlrSF  BedroomAbvGr  YearBuilt
# Id
# 1        TA         TA       856       854             3       2003
# 2        TA         TA      1262         0             3       1976
# 3        TA         TA       920       866             3       2001
# 4        Gd         TA       961       756             3       1915
# 5        TA         TA      1145      1053             4       2000

# %%
data_numeric = pd.get_dummies(data)
data_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalePrice          1460 non-null   int64
#  1   1stFlrSF           1460 non-null   int64
#  2   2ndFlrSF           1460 non-null   int64
#  3   BedroomAbvGr       1460 non-null   int64
#  4   YearBuilt          1460 non-null   int64
#  5   MSZoning_C (all)   1460 non-null   uint8
#  6   MSZoning_FV        1460 non-null   uint8
#  7   MSZoning_RH        1460 non-null   uint8
#  8   MSZoning_RL        1460 non-null   uint8
#  9   MSZoning_RM        1460 non-null   uint8
#  10  Condition1_Artery  1460 non-null   uint8
#  11  Condition1_Feedr   1460 non-null   uint8
#  12  Condition1_Norm    1460 non-null   uint8
#  13  Condition1_PosA    1460 non-null   uint8
#  14  Condition1_PosN    1460 non-null   uint8
#  15  Condition1_RRAe    1460 non-null   uint8
# ...

# %%
data_final = data_numeric.drop(['MSZoning_C (all)','Condition1_Norm','Condition2_Norm','HeatingQC_Fa','BsmtCond_Fa','CentralAir_N','KitchenQual_Fa','GarageCond_Fa'],axis=1)
# double check the result
data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SalePrice          1460 non-null   int64
#  1   1stFlrSF           1460 non-null   int64
#  2   2ndFlrSF           1460 non-null   int64
#  3   BedroomAbvGr       1460 non-null   int64
#  4   YearBuilt          1460 non-null   int64
#  5   MSZoning_FV        1460 non-null   uint8
#  6   MSZoning_RH        1460 non-null   uint8
#  7   MSZoning_RL        1460 non-null   uint8
#  8   MSZoning_RM        1460 non-null   uint8
#  9   Condition1_Artery  1460 non-null   uint8
#  10  Condition1_Feedr   1460 non-null   uint8
#  11  Condition1_PosA    1460 non-null   uint8
#  12  Condition1_PosN    1460 non-null   uint8
#  13  Condition1_RRAe    1460 non-null   uint8
#  14  Condition1_RRAn    1460 non-null   uint8
#  15  Condition1_RRNe    1460 non-null   uint8
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
data_final_train, data_final_test = train_test_split(data_final, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
data_final_train.head()
# Out:
#       SalePrice  1stFlrSF  2ndFlrSF  BedroomAbvGr  YearBuilt  MSZoning_FV  \
# Id
# 211       98000       864         0             2       1925            0
# 319      260000      1372      1274             4       1993            0
# 240      113000       798       689             3       1945            0
# 987      117000      1001       634             2       1910            0
# 1417     122500      1246      1044             4       1885            0
#
#       MSZoning_RH  MSZoning_RL  MSZoning_RM  Condition1_Artery  ...  \
# Id                                                              ...
# 211             0            1            0                  0  ...
# 319             0            1            0                  0  ...
# 240             0            1            0                  0  ...
# 987             0            0            1                  0  ...
# 1417            0            0            1                  0  ...
#
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = preprocessing.StandardScaler()

# %%
sel_num_col = ['SalePrice','YearBuilt','1stFlrSF','2ndFlrSF','BedroomAbvGr']

# %%
data_final_train[sel_num_col] = scaler.fit_transform(data_final_train[sel_num_col])

# %%
data_final_test[sel_num_col] = scaler.fit_transform(data_final_test[sel_num_col])

# %%
data_final_train.head()
# Out:
#       SalePrice  1stFlrSF  2ndFlrSF  BedroomAbvGr  YearBuilt  MSZoning_FV  \
# Id
# 211   -1.042855 -0.765065 -0.787597     -1.042717  -1.524903            0
# 319    1.006390  0.511914  2.140556      1.396261   0.717033            0
# 240   -0.853110 -0.930972  0.795996      0.176772  -0.865510            0
# 987   -0.802511 -0.420683  0.669584     -1.042717  -2.019448            0
# 1417  -0.732938  0.195183  1.611926      1.396261  -2.843689            0
#
#       MSZoning_RH  MSZoning_RL  MSZoning_RM  Condition1_Artery  ...  \
# Id                                                              ...
# 211             0            1            0                  0  ...
# 319             0            1            0                  0  ...
# 240             0            1            0                  0  ...
# 987             0            0            1                  0  ...
# 1417            0            0            1                  0  ...
#
# ...

# %%
df = data_final_train
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=90)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# calculating VIF
# This function is adjusted from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: (default 5) the threshould VIF value. If the VIF of a variable is greater than thresh, it should be removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data. add_constant is a function from statsmodels (see the import above)
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        # If there are multiple variabels with VIF>thresh, only one of them is removed. This is because we want to keep as many variables as possible
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break
            
        return df

# %%
df.columns
# Out:
# Index(['SalePrice', '1stFlrSF', '2ndFlrSF', 'BedroomAbvGr', 'YearBuilt',
#        'MSZoning_FV', 'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM',
#        'Condition1_Artery', 'Condition1_Feedr', 'Condition1_PosA',
#        'Condition1_PosN', 'Condition1_RRAe', 'Condition1_RRAn',
#        'Condition1_RRNe', 'Condition1_RRNn', 'Condition2_Artery',
#        'Condition2_Feedr', 'Condition2_PosA', 'Condition2_PosN',
#        'Condition2_RRAe', 'Condition2_RRAn', 'Condition2_RRNn',
#        'KitchenQual_Ex', 'KitchenQual_Gd', 'KitchenQual_TA', 'HeatingQC_Ex',
#        'HeatingQC_Gd', 'HeatingQC_Po', 'HeatingQC_TA', 'CentralAir_Y',
#        'BsmtCond_Gd', 'BsmtCond_No', 'BsmtCond_Po', 'BsmtCond_TA',
#        'GarageCond_Ex', 'GarageCond_Gd', 'GarageCond_No', 'GarageCond_Po',
#        'GarageCond_TA'],
#       dtype='object')

# %%
# using VIF on the dataset
df_predictors_selected_VIF = drop_column_using_vif_(df.drop('SalePrice', axis=1))
print("The columns remaining after VIF selection are:")
print(df_predictors_selected_VIF.columns)
# Out:
# Dropping: MSZoning_RL
# The columns remaining after VIF selection are:
# Index(['1stFlrSF', '2ndFlrSF', 'BedroomAbvGr', 'YearBuilt', 'MSZoning_FV',
#        'MSZoning_RH', 'MSZoning_RM', 'Condition1_Artery', 'Condition1_Feedr',
#        'Condition1_PosA', 'Condition1_PosN', 'Condition1_RRAe',
#        'Condition1_RRAn', 'Condition1_RRNe', 'Condition1_RRNn',
#        'Condition2_Artery', 'Condition2_Feedr', 'Condition2_PosA',
#        'Condition2_PosN', 'Condition2_RRAe', 'Condition2_RRAn',
#        'Condition2_RRNn', 'KitchenQual_Ex', 'KitchenQual_Gd', 'KitchenQual_TA',
#        'HeatingQC_Ex', 'HeatingQC_Gd', 'HeatingQC_Po', 'HeatingQC_TA',
#        'CentralAir_Y', 'BsmtCond_Gd', 'BsmtCond_No', 'BsmtCond_Po',
#        'BsmtCond_TA', 'GarageCond_Ex', 'GarageCond_Gd', 'GarageCond_No',
#        'GarageCond_Po', 'GarageCond_TA'],
#       dtype='object')

# %%
import statsmodels.api as sm

# %%
model_house_price = sm.OLS(endog=df[['SalePrice']], exog=sm.add_constant(df_predictors_selected_VIF)).fit()
model_house_price.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     90.23
# Date:                Fri, 06 Jan 2023   Prob (F-statistic):          1.07e-293
# Time:                        22:09:56   Log-Likelihood:                -671.10
# No. Observations:                1021   AIC:                             1422.
# Df Residuals:                     981   BIC:                             1619.
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# plot 
plt.scatter(model_house_price.fittedvalues, model_house_price.resid)
# adding title and labels
plt.xlabel('Fitted House Price',fontsize=16)
plt.ylabel('Residual',fontsize=16)
plt.title('Residual vs. Fitted Plot of House Price')
plt.show()

# %%
df_predictors_adding_random = df_predictors_selected_VIF
# using a seed to make the result reproducible
np.random.seed(500)
# adding 'totally_random', which is random noise and shows no relationship with the response variable
df_predictors_adding_random['totally_random'] = np.random.normal(0,5,df_predictors_adding_random.shape[0])
# the model without windspeed
model_house_price_adding_random = sm.OLS(endog=df[['SalePrice']], exog=sm.add_constant(df_predictors_adding_random)).fit()
model_house_price_adding_random.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.783
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                     88.31
# Date:                Fri, 06 Jan 2023   Prob (F-statistic):          1.68e-293
# Time:                        22:09:20   Log-Likelihood:                -669.20
# No. Observations:                1021   AIC:                             1420.
# Df Residuals:                     980   BIC:                             1622.
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#Dividing train set into X_test and y_test
y_train = data_final_train.pop('SalePrice')
X_train = data_final_train

# %%
#Dividing test set into X_test and y_test
y_test = data_final_test.pop('SalePrice')
X_test = data_final_test

# %%
df_predictors_selected_VIF = sm.add_constant(df_predictors_selected_VIF)

# %%
lm = sm.OLS(y_train,df_predictors_selected_VIF).fit()

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     90.23
# Date:                Fri, 06 Jan 2023   Prob (F-statistic):          1.07e-293
# Time:                        22:10:06   Log-Likelihood:                -671.10
# No. Observations:                1021   AIC:                             1422.
# Df Residuals:                     981   BIC:                             1619.
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.2526      0.167     -1.515      0.130      -0.580       0.075
# ...

# %%
# Adding constant
X_test_1 = sm.add_constant(X_test)
X_test_new = X_test_1[df_predictors_selected_VIF.columns]
X_test_new.head()
# Out:
#       const  1stFlrSF  2ndFlrSF  BedroomAbvGr  YearBuilt  MSZoning_FV  \
# Id
# 1437    1.0 -0.795529 -0.810589      0.133271  -0.008329            0
# 58      1.0 -0.806680  1.148506      0.133271   1.096127            0
# 781     1.0  0.288934 -0.810589      0.133271   0.794912            0
# 383     1.0 -0.586442  1.143950      0.133271   1.163063            0
# 1171    1.0 -0.087422 -0.810589      0.133271   0.192481            0
#
#       MSZoning_RH  MSZoning_RM  Condition1_Artery  Condition1_Feedr  ...  \
# Id                                                                   ...
# 1437            0            0                  0                 0  ...
# 58              0            0                  0                 0  ...
# 781             0            0                  0                 0  ...
# 383             0            0                  0                 0  ...
# 1171            0            0                  0                 0  ...
#
# ...

# %%
y_test.head()
# Out:
# Id
# 1437   -0.764598
# 58      0.182784
# 781    -0.072760
# 383     0.394699
# 1171   -0.135088
# Name: SalePrice, dtype: float64

# %%
# Making predictions using the final model
y_pred = lm.predict(X_test_new)
y_pred
# Out:
# Id
# 1437   -0.921288
# 58      0.458020
# 781    -0.148183
# 383     0.585401
# 1171   -0.508185
#           ...
# 510    -0.611791
# 556    -1.139702
# 400     0.527183
# 546     0.862076
# 267    -0.105593
# Length: 438, dtype: float64

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)   
plt.xlabel('y_test ', fontsize=18)                       
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7323990890517527

# %%
y_train_price = lm.predict(df_predictors_selected_VIF)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms Analysis')                   
plt.xlabel('Errors', fontsize = 16)
plt.ylabel('Density', fontsize = 16)
# Out:
# Text(0, 0.5, 'Density')

# %%
# Plot residuals
plt.scatter(y_train_price, y_train_price - y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_pred, y_pred - y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = -2, xmax = 4, color = "red")
plt.show()

# %%
# Plot predictions
plt.scatter(y_train_price, y_train, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_pred, y_test, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([-2, 4], [-2, 4], c = "red")
plt.show()
